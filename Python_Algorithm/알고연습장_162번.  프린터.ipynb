# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/42587

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# priorities	location	return
# [2, 1, 3, 2]	2	1
# [1, 1, 9, 1, 1, 1]	0	5

# %%
priorities =  [1, 1, 9, 1, 1, 1]

# %%
location = 0
value = priorities[location]
priorities[location]='t'
value
# Out:
# 1

# %%
priorities
# Out:
# ['t', 1, 9, 1, 1, 1]

# %%
# priorities[priorities.index('t')] = value

# %%
cnt = 0

# %%
while True:
    temp = priorities.copy()
    print(temp)
    temp[temp.index('t')] = value
    temp_max = max(temp[1:])
    
    if priorities[0] == 't':
        p_0 = value
    else:
        p_0 = priorities[0]

    if p_0 >= temp_max:
        cnt += 1
        if priorities[0]=='t':
            print(cnt)
            break
        else:
            priorities = priorities[1:]

    else:
        priorities = priorities[1:] + priorities[0:1]
# Out:
# ['t', 1, 9, 1, 1, 1]
# [1, 9, 1, 1, 1, 't']
# [9, 1, 1, 1, 't', 1]
# [1, 1, 1, 't', 1]
# [1, 1, 't', 1]
# [1, 't', 1]
# ['t', 1]
# 5

# %% [markdown]
# max 값 때문에 전체 갯수가 1개일때 무한 루프 문제에 빠지게 된다.

# %%
def solution(priorities, location):
    value = priorities[location]
    priorities[location]='t'
    cnt = 0 
    while True:
        temp = priorities.copy()
        temp[temp.index('t')] = value
        temp_max = max(temp[1:])

        if priorities[0] == 't':
            p_0 = value
        else:
            p_0 = priorities[0]
        
        if p_0 >= temp_max:
            cnt += 1
            if priorities[0]=='t':
                return cnt
            else:
                priorities = priorities[1:]

        else:
            priorities = priorities[1:] + priorities[0:1]
            
        if len(priorities)==1:
            return cnt+1
        else:
            pass

# %% [markdown]
# 해결함

# %%
def solution(priorities, location):
    queue =  [(i,p) for i,p in enumerate(priorities)]
    answer = 0
    while True:
        cur = queue.pop(0)
        if any(cur[1] < q[1] for q in queue):
            queue.append(cur)
        else:
            answer += 1
            if cur[0] == location:
                return answer

# %% [markdown]
# any 와 queue 를 활용한 풀이 Good!
