# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12925

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
int('+1234')
# Out:
# 1234

# %%
def solution(s):
    return int(s)
