# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12922

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 3
s = '수박'
answer=''
for i in range(3):
    answer += s[i%2]
print(answer)
# Out:
# 수박수

# %%
def solution(n):
    answer=''
    for i in range(n):
        answer += '수박'[i%2]
    return answer

# %%
solution(4)
# Out:
# '수박수박'
