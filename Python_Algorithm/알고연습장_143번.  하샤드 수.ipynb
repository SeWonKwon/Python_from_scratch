# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12947

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(arr):
    arr_sum = sum([int(x) for x in str(arr)])
    if arr%arr_sum == 0:
        return True
    else:
        return False

# %%
solution(10)
# Out:
# True
