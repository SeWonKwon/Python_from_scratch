# %% [markdown]
# [카카오 인턴] 키패드 누르기
# https://programmers.co.kr/learn/courses/30/lessons/67256

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 문제가 길다는 것은 쉽다는 것이다!!

# %% [markdown]
# numbers	hand	result
# [1, 3, 4, 5, 8, 2, 1, 4, 5, 9, 5]	"right"	"LRLLLRLLRRL"
# [7, 0, 8, 2, 8, 3, 1, 5, 7, 6, 2]	"left"	"LRLLRRLLLRR"
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]	"right"	"LLRLLRLLRL"

# %%
numbers = [1, 3, 4, 5, 8, 2, 1, 4, 5, 9, 5]
hand = "right"

# %%
L_location = (3, 0) # '*'
R_location = (3, 2) # '#'

# %%
distance = ()

# %%
# 1 2 3 
# 4 5 6
# 7 8 9
# * 0 #

# %%
keypad = [['1','2','3'],
          ['4','5','6'],
          ['7','8','9'],
          ['*','0','#']]

# %%
keypad
# Out:
# [['1', '2', '3'], ['4', '5', '6'], ['7', '8', '9'], ['*', '0', '#']]

# %%
keypad[3][0]
# Out:
# '*'

# %%
keypad[L_location[0]][L_location[1]]
# Out:
# '3'

# %%
# 5와의 거리 구해보기

# 5 = (1, 1)
abs(L_location[0]-1)+abs(L_location[1]-1)
# Out:
# 2

# %%
abs(R_location[0]-1)+abs(R_location[1]-1)
# Out:
# 2

# %% [markdown]
# 그러면 숫자를 좌표값으로 바꾸어서 계산하면 바로 거리가 나온다.

# %%
number_to_location = [(3, 1), (0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2), (2, 0), (2, 1), (2 , 2) ]

# %%
number_to_location
# Out:
# [(3, 1),
#  (0, 0),
#  (0, 1),
#  (0, 2),
#  (1, 0),
#  (1, 1),
#  (1, 2),
#  (2, 0),
#  (2, 1),
#  (2, 2)]

# %%
numbers_to_location = [(3, 1)] + [(a, b) for a in range(3) for b in range(3)]

# %%
numbers_to_location
# Out:
# [(3, 1),
#  (0, 0),
#  (0, 1),
#  (0, 2),
#  (1, 0),
#  (1, 1),
#  (1, 2),
#  (2, 0),
#  (2, 1),
#  (2, 2)]

# %%
numbers
# Out:
# [1, 3, 4, 5, 8, 2, 1, 4, 5, 9, 5]

# %%
No_location = [number_to_location[i] for i in numbers]

# %%
No_location
# Out:
# [(0, 0),
#  (0, 2),
#  (1, 0),
#  (1, 1),
#  (2, 1),
#  (0, 1),
#  (0, 0),
#  (1, 0),
#  (1, 1),
#  (2, 2),
#  (1, 1)]

# %%
answer = ''
for num_loc in numbers_to_location:
    L_distance = abs(L_location[0]-num_loc[0])+abs(L_location[1]-num_loc[1])
    R_distance = abs(R_location[0]-num_loc[0])+abs(R_location[1]-num_loc[1])
    if L_distance>R_distance:
        R_location=num_loc
        answer +='R'
        
    elif L_distance<R_distance:
        L_location=num_loc
        answer +='L'
        
    else:
        if hand =='right':
            R_location=num_loc
            answer +='R'
        elif hand =='left':
            L_location=num_loc
            answer +='L'

# %%
answer
# Out:
# 'RLLLRRRRRR'

# %%
def solution(numbers, hand):
    numbers_to_location = [(3, 1)] + [(a, b) for a in range(3) for b in range(3)]
    No_location = [numbers_to_location[i] for i in numbers]
    L_location = (3, 0) # '*'
    R_location = (3, 2) # '#'
#     print(No_location)
    answer = ''
    
    for num_loc in No_location:
        L_distance = abs(L_location[0]-num_loc[0])+abs(L_location[1]-num_loc[1])
        R_distance = abs(R_location[0]-num_loc[0])+abs(R_location[1]-num_loc[1])
#         print(num_loc)
#         print(L_location, R_location)
#         print(L_distance, R_distance)
#         print('------------')
        if num_loc[1] == 0:
            L_location=num_loc
            answer +='L'
        elif num_loc[1] == 2:
            R_location=num_loc
            answer +='R'
        
        elif L_distance>R_distance:
            R_location=num_loc
            answer +='R'

        elif L_distance<R_distance:
            L_location=num_loc
            answer +='L'

        else:
            if hand =='right':
                R_location=num_loc
                answer +='R'
            elif hand =='left':
                L_location=num_loc
                answer +='L'
    return answer

# %%
numbers = [1, 3, 4, 5, 8, 2, 1, 4, 5, 9, 5]
hand = "right"

# %%
print(solution(numbers, hand))
# Out:
# LRLLLRLLRRL

# %%
def solution(numbers, hand):
    numbers_to_location = [(3, 1)] + [(a, b) for a in range(3) for b in range(3)]
    No_location = [numbers_to_location[i] for i in numbers]
    L_location = (3, 0) # '*'
    R_location = (3, 2) # '#'
    
    answer = ''
    
    for num_loc in No_location:
        L_distance = abs(L_location[0]-num_loc[0])+abs(L_location[1]-num_loc[1])
        R_distance = abs(R_location[0]-num_loc[0])+abs(R_location[1]-num_loc[1])
#         print(L_distance, R_distance)
        if L_distance>R_distance:
            R_location=num_loc
            answer +='R'

        elif L_distance<R_distance:
            L_location=num_loc
            answer +='L'

        else:
            if hand =='right':
                R_location=num_loc
                answer +='R'
            elif hand =='left':
                L_location=num_loc
                answer +='L'
    return answer

# %%
def solution(numbers, hand):
    numbers_to_location = [(3, 1)] + [(a, b) for a in range(3) for b in range(3)]
    No_location = [numbers_to_location[i] for i in numbers]
    L_location = (3, 0) # '*'
    R_location = (3, 2) # '#'

    answer = ''
    
    for num_loc in No_location:
        L_distance = abs(L_location[0]-num_loc[0])+abs(L_location[1]-num_loc[1])
        R_distance = abs(R_location[0]-num_loc[0])+abs(R_location[1]-num_loc[1])

        if num_loc[1] == 0:
            L_location=num_loc
            answer +='L'
        elif num_loc[1] == 2:
            R_location=num_loc
            answer +='R'
        
        elif L_distance>R_distance:
            R_location=num_loc
            answer +='R'

        elif L_distance<R_distance:
            L_location=num_loc
            answer +='L'

        else:
            if hand =='right':
                R_location=num_loc
                answer +='R'
            elif hand =='left':
                L_location=num_loc
                answer +='L'
    return answer
