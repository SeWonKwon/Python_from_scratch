# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12935

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr = [4, 3, 2, 1]

# %% [markdown]
# arr = [10]

# %%
min(arr)
# Out:
# 1

# %%
arr.remove(min(arr))

# %%
arr
# Out:
# [4, 3, 2]

# %%
def solution(arr):
    if len(arr)==1:
        return [-1]
    else:
        arr.remove(min(arr))
        return arr

# %%
print(solution(arr))
# Out:
# [4, 3]
