# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12933

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = [1, 2, 3]

# %%
a.sort(reverse=True)

# %%
a
# Out:
# [3, 2, 1]

# %%
def solution(n):
    return int(''.join(sorted([x for x in str(n)[::-1]], reverse=True)))
