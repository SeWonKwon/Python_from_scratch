# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nums = [3,3,3,2,2,4]
n = len(nums)/2
nums = list(set(nums))
nums
# Out:
# [2, 3, 4]

# %%
def solution(nums):
    n = len(nums)/2
    nums = list(set(nums))

    if n >= len(nums):
        return len(nums)
    else:
        return n
# Out:
#   File "<ipython-input-3-53d21871b559>", line 2
#     return len(nums)
#     ^
# SyntaxError: 'return' outside function

# %%
def solution(nums):
    n = len(nums)/2
    nums = list(set(nums))
    return min(n,len(nums))
