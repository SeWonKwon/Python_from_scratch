# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12954

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# x 부터 시작해서 n 개의 즉 x * 1, x * 2, ... x * n

# %%
def solution(x, n):
    return [x * i for i in range(1, n+1)]

# %%
solution(2, 5)
# Out:
# [2, 4, 6, 8, 10]

# %%
solution(-4, 2)
# Out:
# [-4, -8]
