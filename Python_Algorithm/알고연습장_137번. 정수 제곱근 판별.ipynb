# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12934

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 제곱이면 +1 제곱수
# * 아니면 -1 return

# %%
n = 121
a = (n)**(1/2)

# %%
a
# Out:
# 11.0

# %%
a.is_integer()
# Out:
# True

# %%
def solution(n):
    a = (n)**(1/2)
    if a.is_integer():
        return int((a+1)**2)
    else:
        return -1
