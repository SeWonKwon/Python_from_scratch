# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12931

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(N):
    answer=0
    for i in str(N):
        answer+=int(i)
    return answer

# %%
solution(123)
# Out:
# 6

# %%
solution(987)
# Out:
# 24
