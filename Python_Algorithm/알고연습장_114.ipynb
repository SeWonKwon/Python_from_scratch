# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/68935

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 45
# 125

# %%
n = 45
n//3//3
# Out:
# 5

# %%
num_3 = str(0)
while True:
    a, b = divmod(n,3)
    num_3 +=str(b)
    n = a
    if a == 0 :
        break

# %%
num_3
# Out:
# '00021'

# %%
int(num_3, 3)
# Out:
# 7

# %%
n = "0045"
int(n,6)
# Out:
# 29

# %%
def solution(n):
    num_3 = str(0)
    while True:
        a, b = divmod(n, 3)
        num_3 += str(b)
        n = a
        if a == 0 :
            break
    return int(num_3, 3)
