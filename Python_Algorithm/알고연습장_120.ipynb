# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/12906

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr = [1,1,3,3,0,1,1]

# %%
arr = [4,4,4,3,3]

# %%
answer=[]
for i in arr:
    if len(answer)==0:
        answer.append(i)
    if i != answer[-1]:
        answer.append(i)

print(answer)
# Out:
# [1, 3, 0, 1]

# %%
def solution(arr):
    answer=[]
    for i in arr:
        if len(answer)==0:
            answer.append(i)
        if i != answer[-1]:
            answer.append(i)
            
    return answer

# %%
print(solution(arr))
# Out:
# [1, 3, 0, 1]
