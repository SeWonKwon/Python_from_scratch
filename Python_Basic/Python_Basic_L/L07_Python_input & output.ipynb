# %% [markdown]
# # 입력과 출력

# %% [markdown]
# ---

# %% [markdown]
# ## 표준 입출력(Standard Input/Output)

# %% [markdown]
# 1. 표준입력장치 (키보드, 마우스, 웹캠)
# 2. 표준입력함수 ( input())
# 3. 파이썬 프로그램
# 4. 표준출력함수 print()
# 5. 표준출력장치 ( 모니터, 프린터 )

# %% [markdown]
# ### 표준 입력 함수

# %% [markdown]
# * input() 함수: 콘솔 창을 통해서 사용자 입력을 받는 표준 입력 함수
# * input('text') 함수 안에 입력 받기 위한 질문을 텍스트로 넣을 수 있음

# %% [markdown]
# **input()함수로 받은 자료형은 str**

# %%
name = input("이름: ")
print(type(name))
print(name)
# Out:
# 이름: Codechef
# <class 'str'>
# Codechef

# %% [markdown]
# #### [Lab] 섭씨 온도를 화씨 온도로 변환
#
# * 섭씨 온도를 화씨 온도로 변환하는 공식: $F = (C * 1.8) + 32$

# %%
celsius = input('섭씨 온도:')
fahrenheit = (float(celsius) * 1.8) + 32
print("화씨 온도:",fahrenheit)
# Out:
# 섭씨 온도:34
# 화씨 온도: 93.2

# %% [markdown]
# #### [Lab] 구구단 중의 하나의 단을 입력받아 계산
#
# * 출력할 단을 입력
# * 해당 단의 계산 결과 출력

# %%
n = int(input("몇단을 출력할까요?"))
print(f'{n}단:')
for i in range(1, 10):
    print(f'{n} x {i} = {n * i}')
# Out:
# 몇단을 출력할까요?3
# 3단:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27

# %% [markdown]
# ### 표준 출력 함수

# %% [markdown]
# * `print()` 함수: 콘솔 창을 통해서 결과를 출력하는 표준 출력 함수
# * sep='separator': 개체가 분리하는 방법 지정, 기본값은' '
# * end='end' 끝에 출력할 항목 지정, 기본값은 '\n'
# * file: 쓰기 방법이 있는 객체, 기본값은 sys.stdout
# * flush: True일 경우 flush하고, False일 경우 버퍼, 기본값은 False

# %%
print("Hello")
print("Hello", "Chef")
print("Hello", "Chef", sep='---')
print('1','2','3',sep='')
print('1', end='\t')
print('2', end='\t')
print('3')
# Out:
# Hello
# Hello Chef
# Hello---Chef
# 123
# 1	2	3

# %% [markdown]
# #### [Lab] 구구단 출력
#
# * `print()` 함수를 사용하여 각 단마다 횡으로 출력

# %%
for i in range(2, 10):
    for j in range(1, 10):
        print("{0} x {1} = {2}".format(i, j, i * j), end='\t')
    print()
# Out:
# 2 x 1 = 2	2 x 2 = 4	2 x 3 = 6	2 x 4 = 8	2 x 5 = 10	2 x 6 = 12	2 x 7 = 14	2 x 8 = 16	2 x 9 = 18
# 3 x 1 = 3	3 x 2 = 6	3 x 3 = 9	3 x 4 = 12	3 x 5 = 15	3 x 6 = 18	3 x 7 = 21	3 x 8 = 24	3 x 9 = 27
# 4 x 1 = 4	4 x 2 = 8	4 x 3 = 12	4 x 4 = 16	4 x 5 = 20	4 x 6 = 24	4 x 7 = 28	4 x 8 = 32	4 x 9 = 36
# 5 x 1 = 5	5 x 2 = 10	5 x 3 = 15	5 x 4 = 20	5 x 5 = 25	5 x 6 = 30	5 x 7 = 35	5 x 8 = 40	5 x 9 = 45
# 6 x 1 = 6	6 x 2 = 12	6 x 3 = 18	6 x 4 = 24	6 x 5 = 30	6 x 6 = 36	6 x 7 = 42	6 x 8 = 48	6 x 9 = 54
# 7 x 1 = 7	7 x 2 = 14	7 x 3 = 21	7 x 4 = 28	7 x 5 = 35	7 x 6 = 42	7 x 7 = 49	7 x 8 = 56	7 x 9 = 63
# 8 x 1 = 8	8 x 2 = 16	8 x 3 = 24	8 x 4 = 32	8 x 5 = 40	8 x 6 = 48	8 x 7 = 56	8 x 8 = 64	8 x 9 = 72
# 9 x 1 = 9	9 x 2 = 18	9 x 3 = 27	9 x 4 = 36	9 x 5 = 45	9 x 6 = 54	9 x 7 = 63	9 x 8 = 72	9 x 9 = 81

# %% [markdown]
# ---

# %% [markdown]
# ## 파일 입출력(File Input/Output)

# %% [markdown]
# 1. 파일
# 2. 파일입력함수( read(), readline(), readlines() )
# 3. 파이썬 프로그램
# 4. 파일출력함수 ( write(), writelines() )
# 5. 파일

# %% [markdown]
# ### 파일 입출력 과정
#
# * 파일의 입출력 과정은 단계를 가짐
# * 파일을 열고, 파일을 읽거나 쓰고, 파일을 닫는 순서

# %% [markdown]
# 1. 파일 열기
# 2. 파일 읽기 or 파일 쓰기
# 3. 파일 닫기

# %% [markdown]
# ### 파일 열기/닫기
#
# * file.txt 파일을 생성하고, 열고 닫기

# %%
f = open("file.txt", 'w')
f = open('file.txt', 'r')
f.close()

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch 디렉터리
#
# 2021-06-27  오후 04:45    <DIR>          .
# 2021-06-27  오후 04:45    <DIR>          ..
# 2021-06-27  오후 04:26    <DIR>          .ipynb_checkpoints
# 2021-06-27  오전 12:49    <DIR>          Colab,JupyterNotebook,Markdown
# 2021-06-27  오후 04:45                 0 file.txt
# 2021-05-19  오전 02:02    <DIR>          Helpfunction
# 2021-06-25  오전 05:44    <DIR>          Python_Algorithm
# 2021-06-27  오전 12:48    <DIR>          Python_Basic_L
# 2021-06-27  오후 04:44            20,830 _06_입력과_출력.ipynb
# 2021-06-26  오후 12:09         (147,381) 알고연습장_151번. 타겟 넘버.ipynb
#                3개 파일             168,211 바이트
#                7개 디렉터리  78,675,976,192 바이트 남음

# %% [markdown]
# ### 파일 모드(File Mode)

# %% [markdown]
# |파일 모드|설명|
# |:---:|:----|
# |(생략)|`r`과 동일한 모드|
# |`r`|읽기 모드(기본값)|
# |`w`|쓰기 모드, 기존에 파일이 있으면 덮어쓰기|
# |`a`|쓰기 모드, 기존에 파일이 있으면 이어서 쓰기(append)|
# |`+`|읽기/쓰기 모드|
# |`t`|텍스트 모드(기본값), 텍스트 파일을 처리|
# |`b`|이진 모드, 이진 파일을 처리|

# %% [markdown]
# ### 텍스트 파일 쓰기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### write()
#
# * `write()`를 이용하여 파일에 쓰기

# %%
f = open("file.txt", 'w')
f.write("Hello Python")
f.close()

# %%
# Linux
# !cat file.txt 
 # Window
# !type file.txt
# Out:
# Hello Python
# file.txt
#
#
# 지정된 파일을 찾을 수 없습니다.
# 다음 내용 진행 중 오류 발생: #.
# 지정된 파일을 찾을 수 없습니다.
# 다음 내용 진행 중 오류 발생: Window.

# %% [markdown]
# #### writelines()
#
# * `writelines()`를 이용하여 list를 파일에 쓰기

# %%
l = ["One\n", "Two\n", "Three\n"]
f = open('file.txt', 'w')
f.writelines(l)
f.close()

# %%
# Linux
# !cat file.txt 
 # Window
# !type file.txt
# Out:
# One
# Two
# Three

# %% [markdown]
# #### 표준 입력 → 파일 쓰기
#
# * 표준 입력을 `input()` 함수를 통해 입력 받고, `write()` 함수를 통해 파일에 쓰기

# %%
text = input('입력:')
f = open('file.txt', 'w')
f.write(text)
f.close()
# Out:
# 입력:Never Trust a Lazy Code Chef

# %%
# Linux
# !cat file.txt 
 # Window
# !type file.txt
# Out:
# Never Trust a Lazy Code Chef

# %%
text = [str(text + '\n') for text in input("여러 값 입력: ").split()]
f = open("file.txt", 'w')
f.writelines(text)
f.close()
# Out:
# 여러 값 입력: 1 2 3 4 54

# %%
print(text)
# Linux
# !cat file.txt 
 # Window
# !type file.txt
# Out:
# ['1\n', '2\n', '3\n', '4\n', '54\n']
# 1
# 2
# 3
# 4
# 54

# %%
text = ''
x = ""
while x != 'q':
    x = input("반복 입력:")
    text += x +'\n'
    
f = open('file.txt','w')
f.writelines(text)
f.close()
# Out:
# 반복 입력:1
# 반복 입력:2
# 반복 입력:3
# 반복 입력:4
# 반복 입력:5
# 반복 입력:5
# 반복 입력:5
# 반복 입력:5
# 반복 입력:5
# 반복 입력:q

# %%
# Linux
# !cat file.txt 
 # Window
# !type file.txt
# Out:
# 1
# 2
# 3
# 4
# 5
# 5
# 5
# 5
# 5
# q

# %% [markdown]
# ### [Lab] 구구단 결과를 파일에 쓰기
#
# * 구구단 결과를 파일에 쓰기

# %%
f = open('dan.txt', 'w')
for i in range(2, 10):
    f.write(f'{i}단:\n')
    for j in range(1, 10):
        f.write(f'{i} * {j} = {i * j}\n')
    else:
        f.write('\n')
        
f.close()

# %%
# Linux
# !cat dan.txt 
 # Window
# !type dan.txt
# Out:
# 2단:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
#
# 3단:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
#
# 4단:
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
#
# 5단:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
#
# 6단:
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
#
# 7단:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
#
# 8단:
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
#
# 9단:
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81

# %% [markdown]
# ### 텍스트 파일 출력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 텍스트 파일 예제

# %% [markdown]
# * `!echo text` : text를 출력
# * `!echo text > filename` : text를 file을 생성하고 저장
# * `!echo text > filename` : text를 file을 추가해서 저장

# %%
# !echo 동해물과 백두산이 마르고 닳도록~~ > anthem.txt
# !echo 하느님이 보우하사 우리나라 만세~~ >> anthem.txt

# %% [markdown]
# #### readline()
#
# * `readline()`를 이용하여 텍스트 파일을 라인 단위로 읽고 화면에 출력

# %%
f = open('anthem.txt', 'r')
while True:
    line = f.readline()
    if not line: break
    print(line)
    
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록~~
#
# 하느님이 보우하사 우리나라 만세~~

# %% [markdown]
# #### readlines()
#
# * `readlines()`를 이용하여 텍스트 파일의 여러 라인을 읽고 화면에 출력

# %%
f = open('anthem.txt', 'r')
lines = f.readlines()
print(lines)
f.close()
# Out:
# ['동해물과 백두산이 마르고 닳도록~~ \n', '하느님이 보우하사 우리나라 만세~~ \n']

# %%
f = open('anthem.txt', 'r')
lines = f.readlines()
for line in lines:
    print(line)
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록~~
#
# 하느님이 보우하사 우리나라 만세~~

# %% [markdown]
# #### read()
#
# * `read()`를 이용하여 텍스트 파일을 읽고 화면에 출력

# %%
f = open('anthem.txt', 'r')
data = f.read()
print(data)
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록~~
# 하느님이 보우하사 우리나라 만세~~

# %% [markdown]
# #### tell()
#
# * 파일 포인터 위치 변경

# %%
f = open("anthem.txt", 'r')
while True:
    print(f.tell())
    
    line = f.readline()
    if not line: break
    print(line)
    
f.close()
# Out:
# 0
# 동해물과 백두산이 마르고 닳도록~~
#
# 36
# 하느님이 보우하사 우리나라 만세~~
#
# 72

# %% [markdown]
# #### seek()
#
# * 파일 포인터 위치 이동

# %%
f = open("anthem.txt", 'r')
f.seek(36)
line = f.readline()
print(line)
f.seek(0)
line = f.readline()
print(line)
f.close()
# Out:
# 하느님이 보우하사 우리나라 만세~~
#
# 동해물과 백두산이 마르고 닳도록~~

# %% [markdown]
# ### with 문
#
# * 항상 파일을 `open()` 함수로 열고, `close()` 함수로 닫아야 하는 일을 자동으로 처리
# * with문을 이용하면 with 블록 내에서 파일을 열고 벗어나면 파일을 닫음

# %%
f = open('file.txt', 'w')
f.write("Hello Python")
f.close()

# %% [markdown]
# 위와 아래는 같다.

# %%
with open('file.txt', 'w') as f:
    f.write('Hello Python')

# %% [markdown]
# ### [Lab] 표준 입력으로 받은 내용을 파일로 쓰기
#
# * 사용자로부터 표준 입력 받음
# * 받은 내용을 계속 파일 쓰기

# %%
f = open('file.txt', 'w')
line = ''

while True:
    line = input()
    if not line: break
    f.writelines(line + '\n')
    
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 얼쑤~

# %%
# Linux
# !cat dan.txt 
 # Window
# !type file.txt
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 얼쑤~

# %% [markdown]
# ### 텍스트 파일 vs. 이진 파일
#
# * 텍스트 파일(text file): 사람이 읽을 수 있는 텍스트로 구성된 파일
# * 이진 파일(binary file): 텍스트가 아닌 비트 단위의 파일
# * 이진 파일의 종류: 그림, 음악, 영상, 프로그램 파일 등

# %% [markdown]
# <div> <img aling='left' src='attachment:image.png' width='400' /> </div>

# %% [markdown]
# * 이진 파일(이미지) 예제

# %%
# from google.colab import files
# files.upload()

# %%
# !ls
# !dir

# %% [markdown]
# ### 이진 파일 복사
#
# * 하나의 이진 파일을 읽어서 다른 이진 파일로 쓰기 (복사)

# %%
input = open('aaa.jpg', 'rb') # rb : read binary
output = open('aaa2.jpg', 'wb') # wb : write binary

while True:
    fp = input.read(1) # 1 줄씩
    if not fp: break
    output.write(fp)
    
input.close()
output.close()

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch 디렉터리
#
# 2021-06-27  오후 05:28    <DIR>          .
# 2021-06-27  오후 05:28    <DIR>          ..
# 2021-06-27  오후 04:26    <DIR>          .ipynb_checkpoints
# 2021-06-27  오후 05:28            23,482 aaa.jpg
# 2021-06-27  오후 05:28            23,482 aaa2.jpg
# 2021-06-27  오후 05:14                72 anthem.txt
# 2021-06-27  오전 12:49    <DIR>          Colab,JupyterNotebook,Markdown
# 2021-06-27  오후 05:05               914 dan.txt
# 2021-06-27  오후 05:19                73 file.txt
# 2021-05-19  오전 02:02    <DIR>          Helpfunction
# 2021-06-25  오전 05:44    <DIR>          Python_Algorithm
# 2021-06-27  오전 12:48    <DIR>          Python_Basic_L
# 2021-06-27  오후 05:28           717,912 _06_입력과_출력.ipynb
# 2021-06-26  오후 12:09         (147,381) 알고연습장_151번. 타겟 넘버.ipynb
#                7개 파일             913,316 바이트
#                7개 디렉터리  78,666,035,200 바이트 남음

# %% [markdown]
# ## 디렉토리 및 파일 처리

# %% [markdown]
# ### 디렉토리 생성
#
# * 디렉토리와 파일을 다루는 다양한 함수를 제공하는 shutil와 os 라이브러리
# * `mkdir()`: 디렉토리 생성

# %%
import os
import shutil
os.mkdir('test')
os.mkdir('test/1')
os.mkdir('test/2')
os.mkdir('test/3')

# %%
# !ls test
# !dir test
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch\test 디렉터리
#
# 2021-06-27  오후 05:31    <DIR>          .
# 2021-06-27  오후 05:31    <DIR>          ..
# 2021-06-27  오후 05:31    <DIR>          1
# 2021-06-27  오후 05:31    <DIR>          2
# 2021-06-27  오후 05:31    <DIR>          3
#                0개 파일                   0 바이트
#                5개 디렉터리  78,669,975,552 바이트 남음

# %% [markdown]
# ### 디렉토리 및 파일 복사
#
# * `shutil.copy()`: 파일 복사
# * `shutil.copytree()`: 디렉토리 전체 복사

# %%
import shutil
shutil.copy('aaa.jpg', 'aaa3.jpg')
# Out:
# 'aaa3.jpg'

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch 디렉터리
#
# 2021-06-27  오후 05:32    <DIR>          .
# 2021-06-27  오후 05:32    <DIR>          ..
# 2021-06-27  오후 04:26    <DIR>          .ipynb_checkpoints
# 2021-06-27  오후 05:28            23,482 aaa.jpg
# 2021-06-27  오후 05:28            23,482 aaa2.jpg
# 2021-06-27  오후 05:32            23,482 aaa3.jpg
# 2021-06-27  오후 05:14                72 anthem.txt
# 2021-06-27  오전 12:49    <DIR>          Colab,JupyterNotebook,Markdown
# 2021-06-27  오후 05:05               914 dan.txt
# 2021-06-27  오후 05:19                73 file.txt
# 2021-05-19  오전 02:02    <DIR>          Helpfunction
# 2021-06-25  오전 05:44    <DIR>          Python_Algorithm
# 2021-06-27  오전 12:48    <DIR>          Python_Basic_L
# 2021-06-27  오후 05:31    <DIR>          test
# 2021-06-27  오후 05:32           721,006 _06_입력과_출력.ipynb
# 2021-06-26  오후 12:09         (147,381) 알고연습장_151번. 타겟 넘버.ipynb
#                8개 파일             939,892 바이트
#                8개 디렉터리  78,669,336,576 바이트 남음

# %%
import shutil
shutil.copytree('test', 'test2')
# Out:
# 'test2'

# %%
# !dir test2
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch\test2 디렉터리
#
# 2021-06-27  오후 05:31    <DIR>          .
# 2021-06-27  오후 05:31    <DIR>          ..
# 2021-06-27  오후 05:31    <DIR>          1
# 2021-06-27  오후 05:31    <DIR>          2
# 2021-06-27  오후 05:31    <DIR>          3
#                0개 파일                   0 바이트
#                5개 디렉터리  78,670,524,416 바이트 남음

# %% [markdown]
# ### 디렉토리 및 파일 확인
#
# * `isdir()`: 디렉토리 존재 확인
# * `isfile()`: 파일 존재 확인
# * `exists()`: 디렉토리/파일 존재 확인

# %%
import os.path
print(os.path.isdir('test'))
print(os.path.isdir('test/1'))
print(os.path.isdir('test/4'))
print(os.path.isfile('aaa.jpg'))
print(os.path.exists('test2'))
print(os.path.exists('test2/3'))
print(os.path.exists('test3'))
# Out:
# True
# True
# False
# True
# True
# True
# False

# %% [markdown]
# ### 디렉토리 목록 보기
#
# * `os.walk()`: 디렉토리 목록 보기

# %%
import os
for dir_name, dir_list, file_names in os.walk('./'): # 현재 디렉토리
    for file_name in file_names:
        print(os.path.join(dir_name, file_name))
# Out:
# ./aaa.jpg
# ./aaa2.jpg
# ./aaa3.jpg
# ./anthem.txt
# ./dan.txt
# ./file.txt
# ./_06_입력과_출력.ipynb
# ./알고연습장_151번. 타겟 넘버.ipynb
# ./.ipynb_checkpoints\001_Google Colab -checkpoint.ipynb
# ./.ipynb_checkpoints\002_JupyterNoteBook-checkpoint.ipynb
# ./.ipynb_checkpoints\003_Shell commands-checkpoint.ipynb
# ./.ipynb_checkpoints\004_Markdown MD -checkpoint.ipynb
# ./.ipynb_checkpoints\004_Shell commands2-checkpoint.ipynb
# ./.ipynb_checkpoints\L01_Google_Colab,_Jupyter_Notebook,_Markdown-checkpoint.ipynb
# ./.ipynb_checkpoints\L02_Python_Basic-checkpoint.ipynb
# ./.ipynb_checkpoints\L03_Python_Variables, Dtypes, Operators-checkpoint.ipynb
# ./.ipynb_checkpoints\L05_Python_List, Tuple, Dictionary-checkpoint.ipynb
# ./.ipynb_checkpoints\L06_Python_Condition, Loops and Control Statements, Error-checkpoint.ipynb
# ./.ipynb_checkpoints\_06_입력과_출력-checkpoint.ipynb
# ./.ipynb_checkpoints\알고연습장_151번. 타겟 넘버-checkpoint.ipynb
# ./.ipynb_checkpoints\자료형_정리-checkpoint.ipynb
# ./Colab,JupyterNotebook,Markdown\001_Google Colab .ipynb
# ./Colab,JupyterNotebook,Markdown\002_JupyterNoteBook-DESKTOP-BBS5QK2.ipynb
# ./Colab,JupyterNotebook,Markdown\002_JupyterNoteBook.ipynb
# ./Colab,JupyterNotebook,Markdown\003_Shell commands.ipynb
# ./Colab,JupyterNotebook,Markdown\004_Shell commands2.ipynb
# ./Colab,JupyterNotebook,Markdown\005_Markdown MD 마크다운 문법 .ipynb
# ./Colab,JupyterNotebook,Markdown\HHKB_Keyborad_ Layout.ipynb
# ./Colab,JupyterNotebook,Markdown\HHKB_Setting_20210622_for_python programming.hks
# ./Colab,JupyterNotebook,Markdown\.ipynb_checkpoints\002_JupyterNoteBook-checkpoint.ipynb
# ./Colab,JupyterNotebook,Markdown\.ipynb_checkpoints\005_Markdown MD 마크다운 문법 -checkpoint.ipynb
# ./Colab,JupyterNotebook,Markdown\.ipynb_checkpoints\HHKB_Keyborad_ Layout-checkpoint.ipynb
# ./Helpfunction\helpfunction_in_colab_for_vongjur_portf.py
# ./Helpfunction\pytube_incolab.ipynb
# ./Helpfunction\TITLE_web_scrawling.ipynb
# ./Python_Algorithm\001_print_format.ipynb
# ./Python_Algorithm\002_input().ipynb
# ./Python_Algorithm\003_convert_number.ipynb
# ./Python_Algorithm\004_Unicode_ord_chr.ipynb
# ./Python_Algorithm\005_Greedy.ipynb
# ./Python_Algorithm\006_rank.ipynb
# ./Python_Algorithm\007_betwise_and_numberic_convert.ipynb
# ./Python_Algorithm\008_Implementation(구현).ipynb
# ./Python_Algorithm\009_Recursive_function.ipynb
# ./Python_Algorithm\010_lpad_rpad.ipynb
# ./Python_Algorithm\011_약수, 배수, 소수.ipynb
# ./Python_Algorithm\bite.ipynb
# ./Python_Algorithm\List_comprehension.ipynb
# ./Python_Algorithm\Stack_Queue.ipynb
# ./Python_Algorithm\알고연습장_148번. 짝지어 제거하기.ipynb
# ./Python_Algorithm\재귀함수.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\001_print_format-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\002_input()-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\003_convert_number-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\005_Greedy-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\006_rank-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\007_betwise_and_numberic_convert-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\008_Implementation(구현)-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\009_Recursive_function-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\010_lpad_rpad-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\011_약수, 배수, 소수-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\136번. 정수 내림차순으로 배치하기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\139번. 짝수와 홀수-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\140번. 최대공약수와 최소공배수-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\bite-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\List_comprehension-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\Stack_Queue-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_100-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_101-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_102-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_103-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_104-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_105-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_106-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_107-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_108-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_109-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_110-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_111-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_112-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_113-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_114-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_115-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_116-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_117-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_118-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_121-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_122-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_123-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_124-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_125-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_126 문자열 다루기 기본-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_127 서울에서 김서방 찾기 도움말-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_129 소수 찾기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_130 수박수박수박-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_131 문자열을 정수로 바꾸기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_131 시저 암호-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_132 약수의 합-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_133번. 이상한 문자 만들기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_134번. 자릿수 더하기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_135번. 자연수 뒤집어 배열로 만들기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_137번. 정수 제곱근 판별-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_138번. 제일 작은 수 제거하기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_141번. 콜라츠 추측-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_142번. 평균 구하기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_144번.  핸드폰 번호 가리기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_145번. 행렬의 덧셈-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_146번. x만큼 간격이 있는 n개의 숫자-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_147번.  직사각형 별찍기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_148번. 짝지어 제거하기-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_149번. 멀쩡한 사각형-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_150번. 오픈채팅방-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_98-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\알고연습장_99-checkpoint.ipynb
# ./Python_Algorithm\.ipynb_checkpoints\재귀함수-checkpoint.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_121.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_122.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_123.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_124.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_125.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_126 문자열 다루기 기본.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_127 서울에서 김서방 찾기 도움말.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_129 소수 찾기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_130 수박수박수박.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_131 문자열을 정수로 바꾸기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_131 시저 암호.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_132 약수의 합.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_133번. 이상한 문자 만들기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_134번. 자릿수 더하기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_135번. 자연수 뒤집어 배열로 만들기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_136번. 정수 내림차순으로 배치하기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_137번. 정수 제곱근 판별.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_138번. 제일 작은 수 제거하기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_139번. 짝수와 홀수.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_140번. 최대공약수와 최소공배수.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_141번. 콜라츠 추측.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_142번. 평균 구하기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_143번.  하샤드 수.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_144번.  핸드폰 번호 가리기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_145번. 행렬의 덧셈.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_146번. x만큼 간격이 있는 n개의 숫자.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_147번.  직사각형 별찍기.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_149번. 멀쩡한 사각형.ipynb
# ./Python_Algorithm\알고연습장\알고연습장_150번. 오픈채팅방.ipynb
# ./Python_Algorithm\알고연습장\.ipynb_checkpoints\알고연습장_150번. 오픈채팅방-checkpoint.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_100.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_101.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_102.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_103.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_104.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_105.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_106.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_107.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_108.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_109.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_110.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_111.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_112.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_113.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_114.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_115.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_116.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_117.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_118.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_119.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_120.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_98.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\알고연습장_99.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\.ipynb_checkpoints\알고연습장_100-checkpoint.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\.ipynb_checkpoints\알고연습장_119-checkpoint.ipynb
# ./Python_Algorithm\알고연습장\알고연습장 1~ 120\.ipynb_checkpoints\알고연습장_120-checkpoint.ipynb
# ./Python_Basic_L\L01_Google_Colab,_Jupyter_Notebook,_Markdown.ipynb
# ./Python_Basic_L\L02_Python_Basic.ipynb
# ./Python_Basic_L\L03_Python_Variables, Dtypes, Operators.ipynb
# ./Python_Basic_L\L04_Python_String.ipynb
# ./Python_Basic_L\L05_Python_List, Tuple, Dictionary.ipynb
# ./Python_Basic_L\L06_Python_Condition, Loops and Control Statements, Error.ipynb
# ./Python_Basic_L\자료형_정리.ipynb
# ./Python_Basic_L\.ipynb_checkpoints\L04_Python_String-checkpoint.ipynb

# %% [markdown]
# ### 디렉토리 및 파일 삭제
#
# * `os.remove()`: 파일 삭제
# * `shutil.rmtree()`: 디렉토리 안에 모든 파일/디렉토리 삭제

# %%
import os 
os.remove('aaa2.jpg')
os.remove('aaa3.jpg')

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch 디렉터리
#
# 2021-06-27  오후 05:39    <DIR>          .
# 2021-06-27  오후 05:39    <DIR>          ..
# 2021-06-27  오후 04:26    <DIR>          .ipynb_checkpoints
# 2021-06-27  오후 05:28            23,482 aaa.jpg
# 2021-06-27  오후 05:14                72 anthem.txt
# 2021-06-27  오전 12:49    <DIR>          Colab,JupyterNotebook,Markdown
# 2021-06-27  오후 05:05               914 dan.txt
# 2021-06-27  오후 05:19                73 file.txt
# 2021-05-19  오전 02:02    <DIR>          Helpfunction
# 2021-06-25  오전 05:44    <DIR>          Python_Algorithm
# 2021-06-27  오전 12:48    <DIR>          Python_Basic_L
# 2021-06-27  오후 05:31    <DIR>          test
# 2021-06-27  오후 05:31    <DIR>          test2
# 2021-06-27  오후 05:38           724,987 _06_입력과_출력.ipynb
# 2021-06-26  오후 12:09         (147,381) 알고연습장_151번. 타겟 넘버.ipynb
#                6개 파일             896,909 바이트
#                9개 디렉터리  78,668,541,952 바이트 남음

# %%
import shutil
shutil.rmtree('test')
shutil.rmtree('test2')

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch 디렉터리
#
# 2021-06-27  오후 05:41    <DIR>          .
# 2021-06-27  오후 05:41    <DIR>          ..
# 2021-06-27  오후 04:26    <DIR>          .ipynb_checkpoints
# 2021-06-27  오후 05:28            23,482 aaa.jpg
# 2021-06-27  오후 05:14                72 anthem.txt
# 2021-06-27  오전 12:49    <DIR>          Colab,JupyterNotebook,Markdown
# 2021-06-27  오후 05:05               914 dan.txt
# 2021-06-27  오후 05:19                73 file.txt
# 2021-05-19  오전 02:02    <DIR>          Helpfunction
# 2021-06-25  오전 05:44    <DIR>          Python_Algorithm
# 2021-06-27  오전 12:48    <DIR>          Python_Basic_L
# 2021-06-27  오후 05:40           742,266 _06_입력과_출력.ipynb
# 2021-06-26  오후 12:09         (147,381) 알고연습장_151번. 타겟 넘버.ipynb
#                6개 파일             914,188 바이트
#                7개 디렉터리  78,667,395,072 바이트 남음

# %% [markdown]
# ### 파일 크기
#
# * `os.path.getsize()`: 파일의 크기를 바이트 단위로 출력

# %%
import os.path
print(os.path.getsize('aaa.jpg'),'bytes')
# Out:
# 23482 bytes

# %% [markdown]
# ### 파일 압축

# %% [markdown]
# * zipfile: 압축 관련 라이브러리
# * ZipFile(): 압축 파일 열기
# * write(): 압축 파일에 쓰기
# * extractall() : 전체 압축 해제
# * close(): 압축 파일 닫기

# %%
import zipfile
comp = zipfile.ZipFile('new.zip', 'w')
comp.write('aaa.jpg')
comp.close()

# %%
# !dir *.zip
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch 디렉터리
#
# 2021-06-27  오후 05:43            23,594 new.zip
#                1개 파일              23,594 바이트
#                0개 디렉터리  78,665,359,360 바이트 남음

# %%
decomp = zipfile.ZipFile('new.zip', 'r')
decomp.extractall('new')
decomp.close()

# %%
# !dir new
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EA71-33BA
#
#  C:\Users\bigne\OneDrive\WorkJ\Python_from_scratch\new 디렉터리
#
# 2021-06-27  오후 05:45    <DIR>          .
# 2021-06-27  오후 05:45    <DIR>          ..
# 2021-06-27  오후 05:45            23,482 aaa.jpg
#                1개 파일              23,482 바이트
#                2개 디렉터리  78,664,888,320 바이트 남음

# %% [markdown]
# ## 파일 열고 이름 생성 예제 파일
# * Yolo4 할때 만들었던 파일들입니다.

# %%
import os
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-1-44ee11a8d64d> in <module>
#       1 import os
# ----> 2 os.chdir()
#
# TypeError: chdir() missing required argument 'path' (pos 1)

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  'L01_Google_Colab,_Jupyter_Notebook,_Markdown.ipynb',
#  'L02_Python_Basic.ipynb',
#  'L03_Python_Variables, Dtypes, Operators.ipynb',
#  'L04_Python_String.ipynb',
#  'L05_Python_List, Tuple, Dictionary.ipynb',
#  'L06_Python_Condition, Loops and Control Statements, Error.ipynb',
#  'L07_Python_input & output.ipynb',
#  'L08_Python_function.ipynb',
#  'L09_Python_Object & Class.ipynb',
#  'L10_Python_Module & Packages.ipynb',
#  '자료형_정리.ipynb']

# %%
os.path.join("data", 'test')
# Out:
# 'data\\test'

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bigne\\OneDrive'

# %%
# 훈련용 자료 리스트 만들기
def create_list(name):
  import os
  image_files = []
  os.chdir(os.path.join("data", name)) # data밑에 name 변수명 디렉토리로 옮겨라.
  for filename in os.listdir(os.getcwd()): # 현재 있는 디렉토리의 모든 파일명을 가져와라
      if filename.endswith(".jpg"):
          image_files.append("data/"+name+"/" + filename) # 파일명과 위치를 합친 str을 image_files 리스트에 닮아줘.
  os.chdir("..") # 상위 디렉토리로 옮겨주고
  with open(name+".txt", "w") as outfile: # 파일을 만들어줘~
      for image in image_files:
          outfile.write(image)
          outfile.write("\n")
      outfile.close()
  os.chdir("..")
