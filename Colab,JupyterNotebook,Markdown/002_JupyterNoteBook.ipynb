# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# * Jupyter Tip 정리 잘되어 있는곳
#
#     - https://towardsdatascience.com/how-to-effortlessly-optimize-jupyter-notebooks-e864162a06ee

# %% [markdown]
# <div> <img align='left' src='https://slid-capture.s3.ap-northeast-2.amazonaws.com/public/image_upload/1a386f1ff965483189c544bee0897798/bca8b24e-b919-43db-97a8-6338e2016168.png' width='500' /> </div>

# %% [markdown]
# * IPython Shell의 브라우저 기반 그래픽인터페이스
# * 파이썬과 IPython 문장 실행
# * 서식 있는 텍스트와 정적/동적 시각화, 수학 공식 표현

# %% [markdown]
# ## help()
#
# * 파이썬 객체에 대한 요약 정보와 사용법 보기

# %%
help(max)

# %% [markdown]
# ## ?로 설명 보기
#
# * 객체 요약 정보 및 사용법이 있는 docstring 보기

# %%
max?

# %%
li = ['one', 'tow', 'three']
li?

# %%
li.count?

# %%
def power(b, n):
  """b의 n승을 반환"""
  return pow(b, n)

# %%
power(2, 4)
# Out:
# 16

# %%
# Docstring 소환
power?

# %% [markdown]
# ![image.png](https://slid-capture.s3.ap-northeast-2.amazonaws.com/public/image_upload/1a386f1ff965483189c544bee0897798/1b7c36e3-2824-4fd8-b286-88ce96402268.png)

# %%
# Docstring 과 sauce 코드까지 나옮
power??

# %% [markdown]
# ![image.png](https://slid-capture.s3.ap-northeast-2.amazonaws.com/public/image_upload/1a386f1ff965483189c544bee0897798/30e11391-d021-4612-b7dd-7e144afd0465.png)

# %% [markdown]
# ## 탭(tab) 자동완성
#
# * 객체와 모듈, 인터페이스의 내용을 자동 완성

# %%
# 자동완성칸중에 필요한 것이 있으면 tab 키를 누르면 된다.

# %% [markdown]
# ##와일드카드(wildcard) 매칭
#
# * 단어의 중간이나 마지막 글자로 매칭하여 객체나 속성 찾기

# %%
*Error?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
str.*index*?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 매직 명령어(magic commands)
#
# * Jupyter Notebook 환경에서 파이썬 파일 저장 및 실행

# %%
# %%writefile test.py
print('magic command')
# Out:
# Overwriting test.py

# %%
# %run test.py
# Out:
# magic command

# %% [markdown]
# * 코드 실행 시간 측정
#   - % 가 한개 일때는 단일문
#   - %% 여러줄의 코드문

# %%
# %%timeit?

# %%
# %timeit li = [n ** n for n in range(1000)]
# Out:
# 5.07 ms ± 36.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
li = []
for n in range(1000):
  li.append(n ** n)
# Out:
# 5.08 ms ± 20.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 입력과 출력 이력
#
# * In과 Out 객체를 통해 이전 명령어와 명령어의 출력 결과 보기
#
#   - In : 내린 명령어 조회
#   - Out : 나온 결과물
#   - +[index] : 앞에 나온 결과물

# %%
In[6]
# Out:
# 'power(2, 4)'

# %%
Out[6]
# Out:
# 16

# %%
Out[18]
# Out:
# 16

# %%
print("In[18]:" + str(In[18] )+ "\nOut[18]: " + str(Out[18]))
# Out:
# In[18]:Out[6]
# Out[18]: 16

# %% [markdown]
# * `_`를 이용해 이전 출력값 출력하기

# %%
# 이전
print(_)
# Out:
# 16

# %%
# 이전 이전
print(__)
# Out:
# 16

# %%
# 이전 이전 이전
print(___)
# Out:
# power(2, 4)

# %%
_18
# Out:
# 16

# %% [markdown]
# * `%history`를 이용한 입력 이력 살펴보기

# %%
# %history -n 1-7
# Out:
#    1: help(max)
#    2: max?
#    3:
# li = ['one', 'tow', 'three']
# li?
#    4: li.count?
#    5:
# def power(b, n):
#   """b의 n승을 반환"""
#   return pow(b, n)
#    6: power(2, 4)
#    7:
# # Docstring 소환
# power?

# %% [markdown]
# * `%rerun`을 이용해 이전 입력 이력 다시 실행

# %%
# %rerun
# Out:
# === Executing: ===
# %history -n 1-7
# === Output: ===
#    1: help(max)
#    2: max?
#    3:
# li = ['one', 'tow', 'three']
# li?
#    4: li.count?
#    5:
# def power(b, n):
#   """b의 n승을 반환"""
#   return pow(b, n)
#    6: power(2, 4)
#    7:
# # Docstring 소환
# power?

# %% [markdown]
# # Jupyter NoteBook Initial setting

# %% [markdown]
# ## 목차와 힌트창 나오게 하는법
#
# https://cafe.daum.net/oracleoracle/SgNT/116

# %% [markdown]
# ```
# pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install --user
# ```

# %% [markdown]
# ## 워킹디렉토리 설정법
#
# https://m.blog.naver.com/pmw9440/221848755677

# %% [markdown]
# ## ipython update code
#
# ```
# pip install notebook --upgrade
# ```

# %% [markdown]
# ## 쥬피터 테마 설정법
# https://realblack0.github.io/2020/05/13/jupyter-notebook-themes.html

# %% [markdown]
# * jupyterteme 패키지 설치
# ```
# pip install jupyterthemes
# ```
#
# * 추천 테마 및 옵션 적용
#
# ```
# jt -t onedork -fs 115 -nfs 125 -tfs 115 -dfs 115 -ofs 115 -cursc r -cellw 80% -lineh 115 -altmd  -kl -T -N
# ```

# %% [markdown]
# **데스크탑 용**
# - 내가 사용하는 옵션
#
# ```
# jt -t onedork -fs 90 -nfs 100 -tfs 115 -dfs 115 -ofs 115 -cursc r -cellw 95% -lineh 115 -altmd  -kl -T -N
# ```

# %% [markdown]
# ### 현재 내가 사용하는 테마  노트북용
#
# ```
# jt -t solarizedl -fs 90 -nfs 100 -tfs 115 -dfs 115 -ofs 115 -cursc r -cellw 95% -lineh 115 -altmd  -kl -T -N
# ```

# %% [markdown]
# >!jt -t grade3 -fs 90 -nfs 100 -tfs 115 -dfs 115 -ofs 115 -cursc r -cellw 95% -lineh 115 -altmd  -kl -T -N

# %% [markdown]
# ## D2coding font 설치

# %% [markdown]
# https://m.blog.naver.com/websearch/221386387940
#
# ![image.png](https://slid-capture.s3.ap-northeast-2.amazonaws.com/public/image_upload/1a386f1ff965483189c544bee0897798/762631af-78ba-4224-b336-a5f0ee2d3700.png)

# %% [markdown]
# ![image.png](https://slid-capture.s3.ap-northeast-2.amazonaws.com/public/image_upload/1a386f1ff965483189c544bee0897798/675578b9-1f5c-4c02-8488-d77e81b7bb54.png)
